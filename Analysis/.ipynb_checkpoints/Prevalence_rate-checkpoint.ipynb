# %%
from IPython.display import Image
Image("../Images/Logo.jpg")

# %% [markdown]
# # <center>Graduate Project ENEL 698</center>
# <center><a href = "https://github.com/isohels/Graduate-Project">Github Link</a></center>

# %%
Image("../Images/Covid-19.png")

# %% [markdown]
# ## This Notebook constitues of analysis of **Infection prevalence rate and Infection fatality rate** of COVID-19 Canada Specific data.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Data Loading

# %%
df = pd.read_csv("https://health-infobase.canada.ca/src/data/covidLive/covid19-download.csv")

# %% [markdown]
#  - Data Source (https://www.canada.ca/en/public-health/services/diseases/2019-novel-coronavirus-infection.html#a1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4107 entries, 0 to 4106
# Data columns (total 35 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   pruid                4107 non-null   int64
#  1   prname               4107 non-null   object
#  2   prnameFR             4107 non-null   object
#  3   date                 4107 non-null   object
#  4   numconf              4107 non-null   int64
#  5   numprob              4107 non-null   int64
#  6   numdeaths            3988 non-null   float64
#  7   numtotal             4107 non-null   int64
#  8   numtested            4050 non-null   float64
#  9   numrecover           3583 non-null   float64
#  10  percentrecover       3379 non-null   float64
#  11  ratetested           3768 non-null   float64
#  12  numtoday             4107 non-null   int64
#  13  percentoday          4107 non-null   float64
#  14  ratetotal            3837 non-null   float64
# ...

# %% [markdown]
# ### Visualizing Null values in the dataset

# %%
sns.heatmap(df.isnull())

# %%
#### Getting the canada specific data(not the provincial data)

df = df[df['prname']=='Canada']
#df.head()

# %%
df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 286 entries, 2 to 4106
# Data columns (total 35 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   pruid                286 non-null    int64
#  1   prname               286 non-null    object
#  2   prnameFR             286 non-null    object
#  3   date                 286 non-null    datetime64[ns]
#  4   numconf              286 non-null    int64
#  5   numprob              286 non-null    int64
#  6   numdeaths            286 non-null    float64
#  7   numtotal             286 non-null    int64
#  8   numtested            270 non-null    float64
#  9   numrecover           242 non-null    float64
#  10  percentrecover       242 non-null    float64
#  11  ratetested           270 non-null    float64
#  12  numtoday             286 non-null    int64
#  13  percentoday          286 non-null    float64
#  14  ratetotal            286 non-null    float64
# ...

# %% [markdown]
#  - So our data is nicely formatted and we have converted the date column to datetime formating now we will calculate the infection prevalence rate, and fatality rate
#
#
# # Prevalence
# source (https://www.cdc.gov/csels/dsepd/ss1978/lesson3/section2.html)
# ### Definition of prevalence
#
# Prevalence, sometimes referred to as prevalence rate,is the proportion of persons in a population who have a particular disease or attitude at a specified point in time or over a specified period of time.
#
#  - Point Prevalence refers to the prevalence measured at a particular point in time. It is the proportion of persons with a particular disease or attribute on a particular disease or attribute on a particular date.
#  - Period Prevalence refers to prevalence measured over an interval of time. It is the proportion of persons with a particular disease or attribute at any time during the interval.
#
# #### Method of Calculating prevalence of disease
#
# (All new and pre-existing cases during a given time period/Population during the same time period)*100

# %% [markdown]
# # Infection Prevalence rate
#
# - The rate is calculated on number of tested people only.

# %%
plt.figure(figsize=(20,15))
ax = sns.lineplot(x=df['date'],y=(df['numconf']*100/(df['numtested'])), data=df, label='Infection Prevalence rate')
ax.axvline(pd.to_datetime('2020-03-16'),color='r', linestyle='--', lw=2, label = 'Lockdown Announced')
plt.title('Infection Prevalence rate in Canada')
# Out:
# Text(0.5, 1.0, 'Infection Prevalence rate in Canada')

# %% [markdown]
#  - From this graph we can see a high prevalance rate of 6.5% in the month of april, which dropped to around 2% by october.

# %% [markdown]
# # Infection fatality prevalence rate

# %% [markdown]
# - The rate is calculated on number of tested people only.

# %%
plt.figure(figsize=(20,15))
ax = sns.lineplot(x=df['date'],y=(df['numdeaths']*100/df['numtested']), data=df, label='Fatality Prevalence rate')
ax.axvline(pd.to_datetime('2020-03-16'),color='r', linestyle='--', lw=2, label = 'Lockdown Announced')
plt.title('Fatality Prevalence rate in Canada')
# Out:
# Text(0.5, 1.0, 'Fatality Prevalence rate in Canada')

# %% [markdown]
#  - From this graph we can see that fatality prevalence rate also dropped to around 0.1% from 0.4%.
